# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import sklearn
import sklearn.datasets
seed=24

# %%
data=pd.read_csv("../Final-Project/clean.csv")
data.head()
# Out:
#    Unnamed: 0  Age  DailyRate  DistanceFromHome  Education  EmployeeNumber  \
# 0           0   41       1102                 1          2               1
# 1           1   49        279                 8          1               2
# 2           2   37       1373                 2          2               4
# 3           3   33       1392                 3          4               5
# 4           4   27        591                 2          1               7
#
#    EnvironmentSatisfaction  HourlyRate  JobInvolvement  JobLevel  ...  \
# 0                        2          94               3         2  ...
# 1                        3          61               2         2  ...
# 2                        4          92               2         1  ...
# 3                        4          56               3         1  ...
# 4                        1          40               3         1  ...
#
#    JobRole_Manager  JobRole_Manufacturing_Director  JobRole_Research_Director  \
# ...

# %%
data.describe()
# Out:
#         Unnamed: 0          Age    DailyRate  DistanceFromHome    Education  \
# count  1470.000000  1470.000000  1470.000000       1470.000000  1470.000000
# mean    734.500000    36.923810   802.485714          9.192517     2.912925
# std     424.496761     9.135373   403.509100          8.106864     1.024165
# min       0.000000    18.000000   102.000000          1.000000     1.000000
# 25%     367.250000    30.000000   465.000000          2.000000     2.000000
# 50%     734.500000    36.000000   802.000000          7.000000     3.000000
# 75%    1101.750000    43.000000  1157.000000         14.000000     4.000000
# max    1469.000000    60.000000  1499.000000         29.000000     5.000000
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
data=data.drop(columns=['Unnamed: 0'])
data.head()
# Out:
#    Age  DailyRate  DistanceFromHome  Education  EmployeeNumber  \
# 0   41       1102                 1          2               1
# 1   49        279                 8          1               2
# 2   37       1373                 2          2               4
# 3   33       1392                 3          4               5
# 4   27        591                 2          1               7
#
#    EnvironmentSatisfaction  HourlyRate  JobInvolvement  JobLevel  \
# 0                        2          94               3         2
# 1                        3          61               2         2
# 2                        4          92               2         1
# 3                        4          56               3         1
# 4                        1          40               3         1
#
#    JobSatisfaction  ...  JobRole_Manager  JobRole_Manufacturing_Director  \
# 0                4  ...                0                               0
# ...
